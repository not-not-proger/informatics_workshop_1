# %% [markdown]
# # ДЗ №1 СУНЦ МГУ - Numpy practice

# %% [markdown]
# _Задачи позаимствованы из курса ML ФКН ПМИ где они были позаимствованы из курса практикума кафедры ММП факультета ВМК МГУ_

# %% [markdown]
# ### Туториальные задачи
# __(9 баллов)__
#
# Ниже приведены задачи на работу с numpy-массивами. Для каждой из задач нужно привести 2 реализации: одна без использования numpy (cчитайте, что там, где на входе или выходе должны быть numpy array, будут просто списки), а вторая полностью векторизованная (без использования питоновских циклов/map/list comprehension). Невекторизованная реализация каждой из задач оценивается в __0.5 балла__, векторизованная – в __1 балл__.
#
# Реализации без использования векторизации нужно записать в файл functions.py, а векторизованные &mdash; в файл functions_vectorized.py
#
# Для каждой задачи, приведённой ниже сравните скорость работы невекторизованной и векторизованной реализации. С помощью пакета matplotlib постройте графики времени работы в зависимости от размера данных. __Графики должны выглядеть опрятно!__ То есть должны быть подписаны оси, названия графиков, и т.д. Например, ниже представлены хороший и плохой графики:

# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

data_size = np.array([10, 30, 70, 120])
time_non_vectorized = data_size ** 2 + 10
time_vectorized = data_size ** 1.5

f, (ax1, ax2) = plt.subplots(1, 2, figsize=(13, 5))

ax1.plot(data_size, time_non_vectorized)
ax1.plot(data_size, time_vectorized)
ax1.set_title(u"Плохой график")
ax1.set_xlabel(u"Размер данных")
ax1.set_ylabel(u"Время")

ax2.plot(data_size, time_non_vectorized, label=u"Невекторизованная")
ax2.plot(data_size, time_vectorized, label=u"Векторизованная")
ax2.set_title(u"Хороший график")
ax2.set_xlabel(u"Длина массива")
ax2.set_ylabel(u"Время (с)")
ax2.grid()
ax2.legend()

f.show()
# Out:
# C:\Users\nov111\AppData\Local\Temp\ipykernel_1360\3107362156.py:26: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   f.show()

# %% [markdown]
# * __Задача 1__: Подсчитать произведение ненулевых элементов на диагонали прямоугольной матрицы.
#  Например, для X = np.array([[1, 0, 1], [2, 0, 2], [3, 0, 3], [4, 4, 4]]) ответ – 3.

# %%
# import numpy as np
# import functions_vectorized as vf
# import functions as f
# from importlib import reload
# import utils
# reload(utils)
# reload(f)
# reload(vf)
# from utils import build_graph_of_times_of_execution_of_funcs

# build_graph_of_times_of_execution_of_funcs('prod_non_zero_diag', True, True, {'Векторизованная': vf.prod_non_zero_diag, 'Невекторизованная': f.prod_non_zero_diag}, lambda x: np.random.randint(0, 2, (x, x)), False, [lambda x: x, lambda x: x.tolist()], 'Длина диагонали матрицы', 10, 200, 1, 1000)

import utils
reload(utils)
from utils import build_graph_of_times_of_execution_of_funcs, get_times_of_execution_of_funcs, TimesOfExecutionIterator, FunctionIterator

count_of_execution_on_one_data = 1000
data = get_times_of_execution_of_funcs(TimesOfExecutionIterator({'Векторизованная': vf.prod_non_zero_diag, 'Невекторизованная': f.prod_non_zero_diag}, FunctionIterator(lambda x: np.random.randint(0, 2, (x, x)), min=10, max=200, step=1), count_of_execution_on_one_data=count_of_execution_on_one_data))
build_graph_of_times_of_execution_of_funcs(title='prod_non_zero_diag', tested_param='Длина диагонали', data=data, count_of_execution_on_one_data=count_of_execution_on_one_data)
# Out:
# graphes/prod_non_zero_diag
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: title={'center': 'prod_non_zero_diag'}, xlabel='Длина диагонали\n\nКоличество итераций на одних данных: 1000', ylabel='Время (с)'>)

# %% [markdown]
#
#
# * __Задача 2__: Даны два вектора x и y. Проверить, задают ли они одно и то же мультимножество.
#   Например, для x = np.array([1, 2, 2, 4]), y = np.array([4, 2, 1, 2]) ответ – True.

# %%
import functions_vectorized as vf
import functions as f
import numpy as np
# # print(type(np.random.randint(0, 2, 10)))
# reload(f)
# reload(vf)
# import timeit
# import utils
# reload(utils)
# from utils import build_graph_of_times_of_executions_of_funcs

# build_graph_of_times_of_executions_of_funcs('are_multisets_equal', True, True, {'Векторизованная': vf.are_multisets_equal, 'Невекторизованная': f.are_multisets_equal}, lambda x: (np.random.randint(0, 2, x), np.random.randint(0, 2, x)), True, [lambda x: x, lambda x: (x[0].tolist(), x[1].tolist())], 'Длина вектора', 1, 300, 1, 1000)
from importlib import reload
import utils
reload(utils)
from utils import build_graph_of_times_of_execution_of_funcs, get_times_of_execution_of_funcs, TimesOfExecutionIterator, FunctionIterator

count_of_execution_on_one_data = 6000
data = get_times_of_execution_of_funcs(TimesOfExecutionIterator({'Векторизованная': vf.are_multisets_equal, 'Невекторизованная': f.are_multisets_equal}, FunctionIterator(lambda x: (np.random.randint(0, 2, x), np.random.randint(0, 2, x)), min=100, max=200, step=1), unpack_test_data=True, validators=(lambda x: x, lambda x: (x[0].tolist(), x[1].tolist())), count_of_execution_on_one_data=count_of_execution_on_one_data))
build_graph_of_times_of_execution_of_funcs(title='are_multisets_equal', tested_param='Длина вектора', data=data, count_of_execution_on_one_data=count_of_execution_on_one_data)

# %% [markdown]
# * __Задача 3__: Найти максимальный элемент в векторе x среди элементов, перед которыми стоит нулевой.
#  Например, для x = np.array([6, 2, 0, 3, 0, 0, 5, 7, 0]) ответ – 5.

# %%
# from importlib import reload
# import functions as f
# import functions_vectorized as vf
# import numpy as np
# # print(type(np.random.randint(0, 2, 10)))
# reload(f)
# reload(vf)
# import timeit
# import utils
# reload(utils)
# from utils import build_graph_of_times_of_executions_of_funcs

# build_graph_of_times_of_executions_of_funcs('max_after_zero', True, True, {'Векторизованная': vf.max_after_zero, 'Невекторизованная': f.max_after_zero}, lambda x: np.random.randint(0, 10, x), False, [lambda x: x, lambda x: x.tolist()], 'Длина вектора', 100, 500, 1, 500)

import utils
reload(utils)
from utils import build_graph_of_times_of_execution_of_funcs, get_times_of_execution_of_funcs, TimesOfExecutionIterator, FunctionIterator

count_of_execution_on_one_data = 1000
data = get_times_of_execution_of_funcs(TimesOfExecutionIterator({'Векторизованная': vf.max_after_zero, 'Невекторизованная': f.max_after_zero}, FunctionIterator(lambda x: np.random.randint(0, 10, x), min=100, max=500, step=1), count_of_execution_on_one_data=count_of_execution_on_one_data))
build_graph_of_times_of_execution_of_funcs(title='max_after_zero', tested_param='Длина вектора', data=data, count_of_execution_on_one_data=count_of_execution_on_one_data)

# %% [markdown]
#  * __ Задача 4__: Дан трёхмерный массив, содержащий изображение, размера (height, width, numChannels), а также вектор длины numChannels. Сложить каналы изображения с указанными весами, и вернуть результат в виде матрицы размера (height, width). В ноутбуке приведите пример работы функции – преобразуйте цветное изображение в оттенки серого, использовав коэффициенты np.array([0.299, 0.587, 0.114]). Считать реальное изображение можно при помощи функции scipy.misc.imread (если изображение не в формате png, установите пакет pillow).

# %%
# reload(f)
# reload(vf)
# import timeit
# import utils
# reload(utils)
# from utils import build_graph_of_times_of_executions_of_funcs

# build_graph_of_times_of_executions_of_funcs('convert_image', True, True, {'Векторизованная': vf.convert_image, 'Невекторизованная': f.convert_image}, lambda x: (np.random.randint(0, 256, (x, x, 3)), np.array([0.299, 0.587, 0.114])), True, [lambda x: x, lambda x: (x[0].tolist(), x[1].tolist())], 'Сторона изображения (pix)', 1, 300, 1, 1)
import numpy as np
import functions_vectorized as vf
import functions as f
from importlib import reload
import utils
reload(utils)
from utils import build_graph_of_times_of_execution_of_funcs, get_times_of_execution_of_funcs, TimesOfExecutionIterator, FunctionIterator
reload(utils)


count_of_execution_on_one_data = 1
data = get_times_of_execution_of_funcs(TimesOfExecutionIterator({'Векторизованная': vf.convert_image, 'Невекторизованная': f.convert_image}, FunctionIterator(lambda x: (np.random.randint(0, 256, (x, x, 3)), np.array([0.299, 0.587, 0.114])), min=100, max=450, step=1), unpack_test_data=True, validators=(lambda x: x, lambda x: (x[0].tolist(), x[1].tolist())), count_of_execution_on_one_data=count_of_execution_on_one_data))
build_graph_of_times_of_execution_of_funcs(title='convert_image', tested_param='Сторона изображения (pix)', data=data, count_of_execution_on_one_data=count_of_execution_on_one_data)
# Out:
# graphes/convert_image

# %% [markdown]
# * __Задача 5__: Реализовать кодирование длин серий (Run-length encoding). Для некоторого вектора x необходимо вернуть кортеж из двух векторов одинаковой длины. Первый содержит числа, а второй - сколько раз их нужно повторить.
#  Например, для x = np.array([2, 2, 2, 3, 3, 3, 5]) ответ – (np.array([2, 3, 5]), np.array([3, 3, 1])).

# %%
# import numpy as np
# # print(type(np.random.randint(0, 2, 10)))
# reload(f)
# reload(vf)
# import timeit
# import utils
# reload(utils)
# from utils import build_graph_of_times_of_executions_of_funcs

# build_graph_of_times_of_executions_of_funcs('run_length_encoding', True, True, {'Векторизованная': vf.run_length_encoding, 'Невекторизованная': f.run_length_encoding}, lambda x: np.random.randint(0, 10, x), False, [lambda x: x, lambda x: x.tolist()], 'Длина вектора', 1, 300, 1, 500)

import utils
reload(utils)
from utils import build_graph_of_times_of_execution_of_funcs, get_times_of_execution_of_funcs, TimesOfExecutionIterator, FunctionIterator

count_of_execution_on_one_data = 500
data = get_times_of_execution_of_funcs(TimesOfExecutionIterator({'Векторизованная': vf.run_length_encoding, 'Невекторизованная': f.run_length_encoding}, FunctionIterator(lambda x: np.random.randint(0, 10, x), min=1, max=300, step=1), count_of_execution_on_one_data=count_of_execution_on_one_data))
build_graph_of_times_of_execution_of_funcs(title='run_length_encoding', tested_param='Длина вектора', data=data, count_of_execution_on_one_data=count_of_execution_on_one_data)

# %% [markdown]
#
#
# * __Задача 6__: Даны две выборки объектов - X и Y. Вычислить матрицу евклидовых расстояний между объектами. Дополнительно сравните с функцией scipy.spatial.distance.cdist по скорости работы (сравнения приведите ниже в ноутбуке).

# %%
# import math
import scipy

# x = np.array([[0, 2, 1], [0, 3, 1], [0, 6, 1]])
# y = np.array([[0, 2, 1], [0, 10, 12]])
# print(x.shape)
# x = np.repeat(x[None], y.shape[0], 0)
# def f(a, c):
#     print('a', a)
#     print(c)
#     return np.repeat(a[None], c, 0)

# vf = np.vectorize(f)
# # print(vf(y))
# vfunc = np.vectorize(lambda a, b: np.linalg.norm(a - b), signature='(n),(n)->()')
# print(x)
# print(x.shape)
# y = np.apply_along_axis(f, 1, y, x.shape[1])
# print('YYYY', y)
# print(vfunc(x, y))
# # print(np.repeat(y, 2, axis=1))
import numpy as np
from importlib import reload
import functions_vectorized as vf
reload(vf)
reload(np)
import functions as f
import utils
reload(utils)
from utils import build_graph_of_times_of_executions_of_funcs
reload(f)

# np_res = vf.pairwise_distance(np.array([[0, 2, 1], [0, 10, 12]]), np.array([[0, 2, 1], [0, 3, 1], [0, 6, 1]]))
# res = f.pairwise_distance(np.array([[0, 2, 1], [0, 10, 12]]), np.array([[0, 2, 1], [0, 3, 1], [0, 6, 1]]))
# print(np.array_equal(np_res, res))
# print(res)
# print(np_res)
# print(np.array_equal(np_res, scipy.spatial.distance.cdist([[0, 2, 1], [0, 10, 12]], [[0, 2, 1], [0, 3, 1], [0, 6, 1]])))
# nd = 2
# build_graph_of_times_of_executions_of_funcs('pairwise_distance', True, True, {'Векторизованная': vf.pairwise_distance, 'Невекторизованная': f.pairwise_distance, 'SciPy': scipy.spatial.distance.cdist}, lambda x: np.random.randint(0, 10, (2, x, nd)), True, [lambda x: x, lambda x: x.tolist(), lambda x: x.tolist()], 'Количество объектов в каждой выборке', 1, 100, 1, 10, f'Количество измерений: {nd}')

count_of_execution_on_one_data = 10
nd = 2
data = get_times_of_execution_of_funcs(TimesOfExecutionIterator({'Векторизованная': vf.pairwise_distance, 'Невекторизованная': f.pairwise_distance, 'SciPy': scipy.spatial.distance.cdist}, FunctionIterator(lambda x: np.random.randint(0, 10, (2, x, nd)), min=1, max=200, step=1), unpack_test_data=True, validators=[lambda x: x, lambda x: x.tolist(), lambda x: x.tolist()], count_of_execution_on_one_data=count_of_execution_on_one_data))
build_graph_of_times_of_execution_of_funcs(title='pairwise_distance', tested_param='Длина вектора', data=data, count_of_execution_on_one_data=count_of_execution_on_one_data, more_data=f'Кол-во измерений у объектов: {nd}')
# Out:
# C:\Program Files\Python311\Lib\importlib\__init__.py:169: UserWarning: The NumPy module was reloaded (imported a second time). This can in some cases result in small but subtle issues and is discouraged.
#   _bootstrap._exec(spec, module)
# C:\Users\nov111\SublimeTextProjects\SublimeTextProjects\инфпрак\1\src\task\utils.py:169: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# graphes/pairwise_distance

# %% [markdown]
# ### Туториал по Markdown
#
# __(1 балл)__
#
# Напишите краткий (а в данной домашке ещё и почти бесмысленный) отчёт с использованием 4-5 различных вариантов разметки/выделения текста.

# %% [markdown]
# АааААа *аААаАааА* **АаааАааАаАаАаа** аааааааааааааАААААФАааА ***НЕт*** АаааААаааАА **ААааААа**
# ### АААААААААААаАААааААаааааа
# 1. AaaAAa
# 2. AaaaAAAaa
# 3. AAAAaa
#     + AaaaAAaaa
#     + AAaaAAaa
# 4. AAaaAAAAAA
